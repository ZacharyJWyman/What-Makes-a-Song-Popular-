# %%
import pandas as pd

# %%
data = pd.read_csv(r'/Users/austineaton/Projects/spotify_project/allsongs_revised.csv')

# %%
data.drop('Unnamed: 0.1', axis = 1, inplace=True)

# %%
data.head(5)
# Out:
#                    name      artist  release_date  length  acousticness  \
# 0      Hey, Soul Sister       Train          2010   217.0      0.157553
# 1  Love The Way You Lie      Eminem          2010   263.0      0.157553
# 2               TiK ToK       Kesha          2010   200.0      0.070000
# 3           Bad Romance   Lady Gaga          2010   295.0      0.157553
# 4  Just the Way You Are  Bruno Mars          2010   221.0      0.157553
#
#    danceability  instrumentalness  loudness  liveness  tempo  energy  \
# 0          0.67          0.169679      -4.0      0.08   97.0    0.89
# 1          0.75          0.169679      -5.0      0.52   87.0    0.93
# 2          0.76          0.000006      -3.0      0.29  120.0    0.84
# 3          0.70          0.169679      -4.0      0.08  119.0    0.92
# 4          0.64          0.169679      -5.0      0.09  109.0    0.84
#
#    speechiness  valence  time_signature  popularity
# 0         0.04     0.80        3.982955          83
# ...

# %%
import matplotlib.pyplot as pit
import seaborn as sns

# %%
sns.scatterplot(x = data['release_date'], y = data['popularity'])

# %%
sns.scatterplot(x=data['length'], y=data['popularity'])

# %%
sns.scatterplot(x=data['acousticness'], y=data['popularity'])

# %%
sns.scatterplot(x=data['danceability'], y=data['popularity'])

# %%
sns.scatterplot(x=data['instrumentalness'], y=data['popularity'])

# %%
sns.scatterplot(x=data['loudness'], y=data['popularity'])

# %%
sns.scatterplot(x=data['liveness'], y=data['popularity'])

# %%
sns.scatterplot(x=data['tempo'], y=data['popularity'])

# %%
sns.scatterplot(x=data['energy'], y=data['popularity'])

# %%
sns.scatterplot(x=data['speechiness'], y=data['popularity'])

# %%
sns.scatterplot(x=data['valence'], y=data['popularity'])

# %%
sns.scatterplot(x=data['time_signature'], y=data['popularity'])

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, 
             x_vars=['release_date', 'length', 'acousticness', 'danceability', 'instrumentalness', 'loudness', 'liveness', 'tempo', 'energy', 'speechiness', 'valence', 'time_signature'], 
            y_vars=['popularity'],
            kind='reg')

# %%
import statsmodels.api as sm

# %%
import numpy as np

# %%
X = data[[ 'length', 'acousticness', 'danceability', 'instrumentalness', 'loudness', 'liveness', 'tempo', 'energy', 'speechiness', 'valence', 'time_signature']]
y = data['popularity']

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              1249.
# Date:                Mon, 31 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        14:25:50   Log-Likelihood:                         -2682.5
# No. Observations:                 653   AIC:                                      5387.
# Df Residuals:                     642   BIC:                                      5436.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
#Ommit 'liveness', 'speechiness', and 'valence' since their P-values are too large (greater that 0.05)

X = data[[ 'release_date','length', 'acousticness', 'danceability', 'instrumentalness', 'loudness', 'tempo', 'energy', 'time_signature']]
y = data['popularity']

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.955
# Method:                 Least Squares   F-statistic:                              1717.
# Date:                Mon, 31 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        15:20:33   Log-Likelihood:                         -2683.9
# No. Observations:                 653   AIC:                                      5384.
# Df Residuals:                     645   BIC:                                      5420.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
